# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/historical_emissions.csv")

# %%
world = df[df.Country == "World"]
years = list(map(str, range(1990, 2019)))
plt.plot(years, *world[years].to_numpy())
