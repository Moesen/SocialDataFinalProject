# %%
import plotly.express as px
import pandas as pd

# %%
# %cd /Users/kelvin/OneDrive - Danmarks Tekniske Universitet/10_sem/SocialDataFinalProject/web
# Out:
# /Users/kelvin/OneDrive - Danmarks Tekniske Universitet/10_sem/SocialDataFinalProject/web

# %%
data_pcc_country = pd.read_csv(
    "data/pcc_energy_extrapolated_5_country.csv", index_col=0
)
data_socio_country = pd.read_csv("data/socio_extrapolated_5_country.csv", index_col=0)

data_pcc_country = data_pcc_country.set_index(["Entity", "Continent", "Year"])
data_socio_country = data_socio_country.set_index(["Entity", "Continent", "Year"])

df_social_energy = data_pcc_country.join(data_socio_country, how="outer").reset_index()
df_social_energy = (
    df_social_energy.sort_values(["Year", "Entity"]).reset_index().drop(columns="index")
)
df_social_energy["Fraction of Low-carbon energy per capita"] = (
    df_social_energy["Low-carbon energy per capita (kWh)"]
    / df_social_energy["Energy per capita (kWh)"]
)
col_int = [
    "GDP per capita ($)",
    "Child mortality rate (under 5 years - %)",
    "HDI",
    "Life expectancy (years)",
    "Tertiary education (%)",
    "Internet users (%)",
    "Tax revenue of total GDP (%)",
]
df_social_energy = df_social_energy.sort_values(["Year", "Continent", "Entity"])

# %%
df_social_energy.head()
# Out:
#           Entity Continent  Year  Coal per capita (kWh)  \
# 2        Algeria    Africa  1965                 64.864
# 5         Angola    Africa  1965                    NaN
# 21         Benin    Africa  1965                    NaN
# 26      Botswana    Africa  1965                    NaN
# 31  Burkina Faso    Africa  1965                    NaN
#
#     Fossil Fuels per capita (kWh)  Energy per capita (kWh)  \
# 2                         1884.32                 1972.847
# 5                             NaN                      NaN
# 21                            NaN                      NaN
# 26                            NaN                      NaN
# 31                            NaN                      NaN
#
#     Low-carbon energy per capita (kWh)  Gas per capita (kWh)  \
# 2                               88.529               592.031
# 5                                  NaN                   NaN
# 21                                 NaN                   NaN
# 26                                 NaN                   NaN
# 31                                 NaN                   NaN
#
#     Nuclear per capita (kWh)  Oil per capita (kWh)  ...  \
# 2                        0.0              1227.425  ...
# 5                        NaN                   NaN  ...
# 21                       NaN                   NaN  ...
# 26                       NaN                   NaN  ...
# 31                       NaN                   NaN  ...
#
#     Child mortality rate (under 5 years - %)           GDP  Population  HDI  \
# 2                                    0.02453  3.566198e+10  12550880.0  NaN
# 5                                        NaN  1.306298e+10   5770573.0  NaN
# 21                                   0.02855  3.566214e+09   2632361.0  NaN
# 26                                   0.01447  3.293172e+08    559996.0  NaN
# 31                                   0.03255  5.469261e+09   5174874.0  NaN
#
#     Life expectancy (years)  Obesity_Rate  Tertiary education (%)  \
# 2                    48.394           NaN                     NaN
# 5                    39.102           NaN                     NaN
# 21                   39.615           NaN                     NaN
# 26                   51.547           NaN                     0.0
# 31                   36.815           NaN                     NaN
#
#     Internet users (%)  Tax revenue of total GDP (%)  \
# 2                  NaN                           NaN
# 5                  NaN                           NaN
# 21                 NaN                           NaN
# 26                 NaN                           NaN
# 31                 NaN                           NaN
#
#     Fraction of Low-carbon energy per capita
# 2                                   0.044874
# 5                                        NaN
# 21                                       NaN
# 26                                       NaN
# 31                                       NaN
#
# [5 rows x 27 columns]

# %%
df_group_by_year_and_continent = df_social_energy.groupby(["Year", "Continent"]).mean()
df_group_by_year_and_continent = df_group_by_year_and_continent.join(df_group_by_year_and_continent["Fraction of Low-carbon energy per capita"].groupby("Year").mean(), on="Year", rsuffix="_global")

# %%
plot_data = df_group_by_year_and_continent.reset_index()

# %%
fig = px.line(plot_data, x="Year", y=["Fraction of Low-carbon energy per capita", "Fraction of Low-carbon energy per capita_global"], color="Continent")
fig.show()

# %%
plot_data
# Out:
#      Year      Continent  Coal per capita (kWh)  \
# 0    1965         Africa            3790.117000
# 1    1965           Asia             653.129375
# 2    1965         Europe           14308.688875
# 3    1965  North America            6373.604000
# 4    1965        Oceania           12570.652000
# ..    ...            ...                    ...
# 325  2019           Asia            5006.679828
# 326  2019         Europe            4672.003424
# 327  2019  North America            3866.404750
# 328  2019        Oceania           11532.020500
# 329  2019  South America            1004.393429
#
#      Fossil Fuels per capita (kWh)  Energy per capita (kWh)  \
# 0                      5997.571250              6119.750750
# 1                     14750.907042             14919.781333
# 2                     28420.649292             32630.963500
# 3                     41243.940750             46317.462500
# 4                     27624.577500             34615.338000
# ..                             ...                      ...
# 325                   46585.176552             37655.429740
# 326                   28815.353939             42642.691475
# 327                   73771.139500             32807.474143
# 328                   47175.133500             21853.821556
# 329                   11958.625143             19698.428286
#
#      Low-carbon energy per capita (kWh)  Gas per capita (kWh)  \
# 0                            122.184750            160.426000
# 1                            168.886083           2128.861583
# 2                           4210.340208            709.994208
# 3                           5073.558250          11556.268000
# 4                           6990.788500              1.302500
# ..                                  ...                   ...
# 325                         1458.935724          19431.467621
# 326                        14735.241455           8519.472061
# 327                        12576.030000          47365.730000
# 328                        12211.268000          13474.771000
# 329                         4243.231571           4293.827429
#
#      Nuclear per capita (kWh)  Oil per capita (kWh)  \
# 0                    0.000000           2047.028000
# 1                    0.029375          11968.916250
# 2                   42.733167          13401.966125
# 3                   17.911750          23314.069000
# 4                    0.000000          15052.622500
# ..                        ...                   ...
# 325                437.297690          22147.029207
# 326               3254.766061          15623.878455
# 327               3321.260250          22539.004750
# 328                  0.000000          22168.342500
# 329                 93.729571           6660.404714
#
#      Renewables per capita (kWh)  ...           GDP    Population       HDI  \
# 0                       0.122185  ...  1.147655e+10  5.735977e+06       NaN
# 1                       0.168857  ...  9.712463e+10  3.788909e+07       NaN
# 2                       4.167607  ...  1.872392e+11  1.379712e+07       NaN
# 3                       5.055647  ...  2.713056e+11  7.949235e+06       NaN
# 4                       6.990788  ...  1.154496e+11  8.052941e+05       NaN
# ..                           ...  ...           ...           ...       ...
# 325                     1.021638  ...  1.169719e+12  9.200156e+07  0.733894
# 326                    11.480475  ...  6.186380e+11  1.623934e+07  0.865098
# 327                     9.254770  ...  1.260329e+12  1.545906e+07  0.746217
# 328                    12.211268  ...  7.047866e+11  1.909738e+06  0.713364
# 329                     4.149502  ...  5.941321e+11  3.051424e+07  0.750833
#
#      Life expectancy (years)  Obesity_Rate  Tertiary education (%)  \
# 0                  44.825055           NaN                1.045154
# 1                  55.398700           NaN                5.135106
# 2                  69.818000           NaN               26.209694
# 3                  62.480632           NaN                5.102036
# 4                  58.686545           NaN                6.739538
# ..                       ...           ...                     ...
# 325                74.844900     15.950000               39.303985
# 326                79.855000     24.830000               67.901296
# 327                77.150421     24.330435               43.081702
# 328                73.917318     41.093333               87.118912
# 329                75.891857     23.133333               66.664628
#
#      Internet users (%)  Tax revenue of total GDP (%)  \
# 0                   NaN                           NaN
# 1                   NaN                           NaN
# 2                   NaN                           NaN
# 3                   NaN                           NaN
# 4                   NaN                           NaN
# ..                  ...                           ...
# 325           62.519581                     16.655403
# 326           84.332851                     35.188104
# 327           66.251304                     20.835419
# 328           50.082469                     22.057390
# 329           62.201225                     21.103242
#
#      Fraction of Low-carbon energy per capita  \
# 0                                    0.072551
# 1                                    0.043153
# 2                                    0.124101
# 3                                    0.091539
# 4                                    0.215570
# ..                                        ...
# 325                                  0.057549
# 326                                  0.261759
# 327                                  0.144832
# 328                                  0.217638
# 329                                  0.272105
#
#      Fraction of Low-carbon energy per capita_global
# 0                                           0.109422
# 1                                           0.109422
# 2                                           0.109422
# 3                                           0.109422
# 4                                           0.109422
# ..                                               ...
# 325                                         0.165856
# 326                                         0.165856
# 327                                         0.165856
# 328                                         0.165856
# 329                                         0.165856
#
# [330 rows x 27 columns]
